# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files

print('Please select the StudentsPerformance.csv file to upload:')
uploaded = files.upload()
# Out:
# Please select the StudentsPerformance.csv file to upload:
#      <input type="file" id="files-28c84c4c-1d8d-4643-804c-72d555ed60c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-28c84c4c-1d8d-4643-804c-72d555ed60c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
data=pd.read_csv("StudentsPerformance.csv")
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
x=data.drop("math score",axis=1)
y=data["math score"]

# %%
y
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
x
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  reading score  writing score
# 0                      none             72             74
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(
    x,y,test_size=0.2,random_state=42
)

# %%
x_train
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 29   female        group D             master's degree      standard
# 535  female        group C           bachelor's degree  free/reduced
# 695  female        group D                some college  free/reduced
# 557    male        group C             master's degree  free/reduced
# 836    male        group E                 high school      standard
# ..      ...            ...                         ...           ...
# 106  female        group D             master's degree      standard
# 270    male        group C           bachelor's degree      standard
# 860  female        group C          associate's degree      standard
# 435    male        group C                some college  free/reduced
# 102  female        group D          associate's degree      standard
#
#     test preparation course  reading score  writing score
# 29                     none             70             75
# ...

# %%
y_train
# Out:
# 29     62
# 535    66
# 695    79
# 557    61
# 836    73
#        ..
# 106    87
# 270    69
# 860    53
# 435    50
# 102    85
# Name: math score, Length: 800, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

# %%
num_cols=x.select_dtypes(include=[np.number]).columns
cat_cols=x.select_dtypes(include=["object"]).columns
preprocessor=ColumnTransformer([
    ("num",StandardScaler(),num_cols),
    ("cat",OneHotEncoder(),cat_cols)
]
)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num', StandardScaler(),
#                                  Index(['reading score', 'writing score'], dtype='object')),
#                                 ('cat', OneHotEncoder(),
#                                  Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course'],
#       dtype='object'))])

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.pipeline import Pipeline
model=Pipeline([
    ("prep",preprocessor),
    ("reg",LinearRegression())
])
model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['reading score', 'writing score'], dtype='object')),
#                                                  ('cat', OneHotEncoder(),
#                                                   Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course'],
#       dtype='object'))])),
#                 ('reg', LinearRegression())])

# %%
preds = model.predict(x_test)
preds
# Out:
# array([76.3879697 , 58.88597004, 76.99026483, 76.85180448, 87.62737816,
#        79.0140238 , 64.65460865, 53.00791885, 74.18471015, 49.21353815,
#        52.94765047, 36.66906418, 67.9139255 , 52.27725558, 86.71848338,
#        70.53070205, 51.95556639, 46.8314386 , 48.82375101, 52.72669531,
#        73.88582984, 38.88612362, 57.38074421, 36.32839723, 78.14908978,
#        81.79995075, 75.3849409 , 46.1184787 , 31.03596334, 49.90094972,
#        65.98409138, 70.4116652 , 60.5061564 , 83.73986218, 84.43184961,
#        46.07265627, 76.10135181, 70.20596817, 65.85782103,  3.76186106,
#        78.49792748, 67.25291552, 67.97175998, 60.2734092 , 79.67385074,
#        67.60005539, 72.24589185, 24.76000748, 85.95581153, 70.08842684,
#        75.41268803, 66.79864565, 81.16502181, 45.6635254 , 66.11051928,
#        67.32545668, 86.13600492, 58.72739768, 82.23614367, 81.21768838,
#        47.23421792, 72.04512129, 70.64302698, 55.92646405, 86.31798368,
# ...

# %%
y_test
# Out:
# 521    91
# 737    53
# 740    80
# 660    74
# 411    84
#        ..
# 408    52
# 332    62
# 208    74
# 613    65
# 78     61
# Name: math score, Length: 200, dtype: int64

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, preds)
rmse = np.sqrt(mse)
print(rmse)
# Out:
# 5.393993869732841

# %%
students = [
    {
        "gender": "male",
        "race/ethnicity": "group C",
        "parental level of education": "high school",
        "lunch": "free/reduced",
        "test preparation course": "none",
        "reading score": 60,
        "writing score": 58
    },
    {
        "gender": "female",
        "race/ethnicity": "group A",
        "parental level of education": "master's degree",
        "lunch": "standard",
        "test preparation course": "completed",
        "reading score": 88,
        "writing score": 90
    }
]

df = pd.DataFrame(students)
preds = model.predict(df)

for i, p in enumerate(preds):
    print(f"Student {i+1} predicted math score: {p:.2f}")
# Out:
# Student 1 predicted math score: 61.91
# Student 2 predicted math score: 77.14

# %%
import joblib

joblib.dump(model, 'student_model.pkl')

model = joblib.load('student_model.pkl')

# %%
print("Enter student details:")

gender = input("Gender (male/female): ")
race = input("Race/Ethnicity (group A/B/C/D/E): ")
parent_edu = input("Parental education (some high school/high school/some college/associate\'s degree/bachelor\'s degree/master\'s degree): ")
lunch = input("Lunch (standard or free/reduced): ")
prep = input("Test preparation (completed/none): ")

reading = int(input("Reading score: "))
writing = int(input("Writing score: "))


student = {
    "gender": gender,
    "race/ethnicity": race,
    "parental level of education": parent_edu,
    "lunch": lunch,
    "test preparation course": prep,
    "reading score": reading,
    "writing score": writing
}

student_df = pd.DataFrame([student])
prediction = model.predict(student_df)
print("Predicted Math Score:", round(prediction[0], 2))
# Out:
# Enter student details:
# Gender (male/female): male
# Race/Ethnicity (group A/B/C/D/E): group A
# Parental education (some high school/high school/some college/associate's degree/bachelor's degree/master's degree): some college
# Lunch (standard or free/reduced): standard
# Test preparation (completed/none): none
# Reading score: 90
# Writing score: 90
# Predicted Math Score: 96.37
